# %%
import numpy as np
import pandas as pd

# %%
mhd = pd.read_csv('/content/Mental Health Dataset - Mental Health Dataset.csv')

# %%
mhd.head()
# Out:
#          Timestamp  Gender        Country Occupation self_employed  \
# 0  8/27/2014 11:29  Female  United States  Corporate           NaN
# 1  8/27/2014 11:31  Female  United States  Corporate           NaN
# 2  8/27/2014 11:32  Female  United States  Corporate           NaN
# 3  8/27/2014 11:37  Female  United States  Corporate            No
# 4  8/27/2014 11:43  Female  United States  Corporate            No
#
#   family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# 0             No       Yes    1-14 days            Yes             No
# 1            Yes       Yes    1-14 days            Yes             No
# 2            Yes       Yes    1-14 days            Yes             No
# 3            Yes       Yes    1-14 days            Yes             No
# 4            Yes       Yes    1-14 days            Yes             No
#
#   Mental_Health_History Mood_Swings Coping_Struggles Work_Interest  \
# 0                   Yes      Medium               No            No
# ...

# %%
mhd.tail()
# Out:
#               Timestamp Gender        Country Occupation self_employed  \
# 166728  8/28/2014 17:46   Male  United States   Business            No
# 166729  8/28/2014 17:47   Male  United States   Business           Yes
# 166730  8/28/2014 17:50   Male  United States   Business            No
# 166731  8/28/2014 17:56   Male  United States   Business            No
# 166732     8/28/2014 17    NaN            NaN        NaN           NaN
#
#        family_history treatment      Days_Indoors Growing_Stress  \
# 166728             No        No  Go out Every day            Yes
# 166729             No        No  Go out Every day            Yes
# 166730             No        No  Go out Every day            Yes
# 166731            Yes       Yes  Go out Every day            Yes
# 166732            NaN       NaN               NaN            NaN
#
#        Changes_Habits Mental_Health_History Mood_Swings Coping_Struggles  \
# ...

# %%
mhd.describe()
# Out:
#               Timestamp  Gender        Country Occupation self_employed  \
# count            166733  166732         166732     166732        163570
# unique              581       2             35          5             2
# top     8/27/2014 11:43    Male  United States  Corporate            No
# freq               1364  114218         100220      37244        148085
#
#        family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# count          166732    166732       166732         166732         166732
# unique              2         2            5              3              3
# top                No       Yes   31-60 days            Yes            Yes
# freq            95135     89371        36720          60121          64013
#
#        Mental_Health_History Mood_Swings Coping_Struggles Work_Interest  \
# count                 166732      166732           166732        166732
# unique                     3           3                2             3
# ...

# %%
mhd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 166733 entries, 0 to 166732
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Timestamp                166733 non-null  object
#  1   Gender                   166732 non-null  object
#  2   Country                  166732 non-null  object
#  3   Occupation               166732 non-null  object
#  4   self_employed            163570 non-null  object
#  5   family_history           166732 non-null  object
#  6   treatment                166732 non-null  object
#  7   Days_Indoors             166732 non-null  object
#  8   Growing_Stress           166732 non-null  object
#  9   Changes_Habits           166732 non-null  object
#  10  Mental_Health_History    166732 non-null  object
#  11  Mood_Swings              166732 non-null  object
#  12  Coping_Struggles         166732 non-null  object
# ...

# %%
mhd.dtypes
# Out:
# Timestamp                  object
# Gender                     object
# Country                    object
# Occupation                 object
# self_employed              object
# family_history             object
# treatment                  object
# Days_Indoors               object
# Growing_Stress             object
# Changes_Habits             object
# Mental_Health_History      object
# Mood_Swings                object
# Coping_Struggles           object
# Work_Interest              object
# Social_Weakness            object
# mental_health_interview    object
# care_options               object
# dtype: object

# %%
mhd.value_counts()
# Out:
# Timestamp        Gender  Country         Occupation  self_employed  family_history  treatment  Days_Indoors        Growing_Stress  Changes_Habits  Mental_Health_History  Mood_Swings  Coping_Struggles  Work_Interest  Social_Weakness  mental_health_interview  care_options
# 8/27/2014 12:33  Male    United States   Business    No             No              No         More than 2 months  Yes             No              Maybe                  Medium       No                Maybe          Yes              No                       No              2
#                                                                                                                                    Maybe           Yes                    Medium       Yes               No             Maybe            No                       No              2
# ...

# %%
mhd.duplicated().sum()
# Out:
# np.int64(1293)

# %%
mhd.shape
# Out:
# (166733, 17)

# %%
mhd.isnull().sum()
# Out:
# Timestamp                     0
# Gender                        1
# Country                       1
# Occupation                    1
# self_employed              3163
# family_history                1
# treatment                     1
# Days_Indoors                  1
# Growing_Stress                1
# Changes_Habits                1
# Mental_Health_History         1
# Mood_Swings                   1
# Coping_Struggles              1
# Work_Interest                 1
# Social_Weakness               1
# mental_health_interview       1
# care_options                  1
# dtype: int64

# %%
mhd.isnull().sum().sum()
# Out:
# np.int64(3178)

# %%
mhd.dropna()
# Out:
#               Timestamp  Gender        Country Occupation self_employed  \
# 3       8/27/2014 11:37  Female  United States  Corporate            No
# 4       8/27/2014 11:43  Female  United States  Corporate            No
# 5       8/27/2014 11:49  Female         Poland  Corporate            No
# 6       8/27/2014 11:51  Female      Australia  Corporate            No
# 7       8/27/2014 11:52  Female  United States  Corporate            No
# ...                 ...     ...            ...        ...           ...
# 166727  8/28/2014 17:36    Male  United States   Business            No
# 166728  8/28/2014 17:46    Male  United States   Business            No
# 166729  8/28/2014 17:47    Male  United States   Business           Yes
# 166730  8/28/2014 17:50    Male  United States   Business            No
# 166731  8/28/2014 17:56    Male  United States   Business            No
#
#        family_history treatment      Days_Indoors Growing_Stress  \
# ...

# %%
mhd.dropna(axis=1)
# Out:
#               Timestamp
# 0       8/27/2014 11:29
# 1       8/27/2014 11:31
# 2       8/27/2014 11:32
# 3       8/27/2014 11:37
# 4       8/27/2014 11:43
# ...                 ...
# 166728  8/28/2014 17:46
# 166729  8/28/2014 17:47
# 166730  8/28/2014 17:50
# 166731  8/28/2014 17:56
# 166732     8/28/2014 17
#
# [166733 rows x 1 columns]

# %%
mhd.fillna("Unknown")
# Out:
#               Timestamp   Gender        Country Occupation self_employed  \
# 0       8/27/2014 11:29   Female  United States  Corporate       Unknown
# 1       8/27/2014 11:31   Female  United States  Corporate       Unknown
# 2       8/27/2014 11:32   Female  United States  Corporate       Unknown
# 3       8/27/2014 11:37   Female  United States  Corporate            No
# 4       8/27/2014 11:43   Female  United States  Corporate            No
# ...                 ...      ...            ...        ...           ...
# 166728  8/28/2014 17:46     Male  United States   Business            No
# 166729  8/28/2014 17:47     Male  United States   Business           Yes
# 166730  8/28/2014 17:50     Male  United States   Business            No
# 166731  8/28/2014 17:56     Male  United States   Business            No
# 166732     8/28/2014 17  Unknown        Unknown    Unknown       Unknown
#
#        family_history treatment      Days_Indoors Growing_Stress  \
# ...

# %%
mhd.isnull().sum()
# Out:
# Timestamp                     0
# Gender                        1
# Country                       1
# Occupation                    1
# self_employed              3163
# family_history                1
# treatment                     1
# Days_Indoors                  1
# Growing_Stress                1
# Changes_Habits                1
# Mental_Health_History         1
# Mood_Swings                   1
# Coping_Struggles              1
# Work_Interest                 1
# Social_Weakness               1
# mental_health_interview       1
# care_options                  1
# dtype: int64
